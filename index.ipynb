# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('data.sqlite')
cur = conn.cursor()

# %%
cur.execute('''SELECT firstName, lastName, city, state FROM employees JOIN offices USING(officeCode) ORDER BY firstName, lastName;''').fetchall()
# Out:
# [('Andy', 'Fixter', 'Sydney', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Barry', 'Jones', 'London', ''),
#  ('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Larry', 'Bott', 'London', ''),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', ''),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Tom', 'King', 'Sydney', ''),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
cur.execute('''SELECT customerNumber, orderNumber, orderDate, status FROM customers JOIN orders USING(customerNumber); ''').fetchall()
# Out:
# [('103', '10123', '2003-05-20', 'Shipped'),
#  ('103', '10298', '2004-09-27', 'Shipped'),
#  ('103', '10345', '2004-11-25', 'Shipped'),
#  ('112', '10124', '2003-05-21', 'Shipped'),
#  ('112', '10278', '2004-08-06', 'Shipped'),
#  ('112', '10346', '2004-11-29', 'Shipped'),
#  ('114', '10120', '2003-04-29', 'Shipped'),
#  ('114', '10125', '2003-05-21', 'Shipped'),
#  ('114', '10223', '2004-02-20', 'Shipped'),
#  ('114', '10342', '2004-11-24', 'Shipped'),
#  ('114', '10347', '2004-11-29', 'Shipped'),
#  ('119', '10275', '2004-07-23', 'Shipped'),
#  ('119', '10315', '2004-10-29', 'Shipped'),
#  ('119', '10375', '2005-02-03', 'Shipped'),
#  ('119', '10425', '2005-05-31', 'In Process'),
#  ('121', '10103', '2003-01-29', 'Shipped'),
#  ('121', '10158', '2003-10-10', 'Shipped'),
#  ('121', '10309', '2004-10-15', 'Shipped'),
#  ('121', '10325', '2004-11-05', 'Shipped'),
#  ('124', '10113', '2003-03-26', 'Shipped'),
#  ('124', '10135', '2003-07-02', 'Shipped'),
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
cur.execute('''SELECT * FROM orders JOIN orderDetails USING(orderNumber);''').fetchall()
# Out:
# [('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_1749',
#   '30',
#   '136.00',
#   '3'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_2248',
#   '50',
#   '55.09',
#   '2'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S18_4409',
#   '22',
#   '75.46',
#   '4'),
#  ('10100',
#   '2003-01-06',
#   '2003-01-13',
#   '2003-01-10',
#   'Shipped',
#   '',
#   '363',
#   'S24_3969',
#   '49',
#   '35.29',
#   '1'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   'S18_2325',
#   '25',
#   '108.06',
#   '4'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
#   '2003-01-11',
#   'Shipped',
#   'Check on availability.',
#   '128',
#   'S18_2795',
#   '26',
#   '167.06',
#   '1'),
#  ('10101',
#   '2003-01-09',
#   '2003-01-18',
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and all the product information for each product in the order.

# %%
cur.execute('''SELECT ''')

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
